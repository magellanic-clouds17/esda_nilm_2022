# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# read vw_train.csv

train_data_path = r'C:\Users\Latitude\Desktop\Kaggle\esda_nilm_2022\data\raw\vw_train.csv'
df = pd.read_csv(train_data_path, index_col=False, dtype={'id': int})
# explorative data analysis
# check shape of data, number of rows and columns, unique values, missing values, data types, etc.

df.shape 
# (67264, 31)

df.columns
# Index(['Unnamed: 0', 'id', 'activePower', 'activePowerDelta', 'reactivePower',
#        'apparentPower', 'current', 'voltage', 'phase', 'hertz', 'transient1',
#        'transient2', 'transient3', 'transient4', 'transient5', 'transient6',
#        'transient7', 'transient8', 'transient9', 'transient10',
#        'harmonicDelta1', 'harmonicDelta2', 'harmonicDelta3', 'harmonicDelta4',
#        'harmonicDelta5', 'harmonicDelta6', 'harmonicDelta7', 'harmonicDelta8',
#        'harmonicDelta9', 'timestamp', 'appliances'],
#       dtype='object')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67264 entries, 0 to 67263
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        67264 non-null  int64
#  1   id                67264 non-null  int32
#  2   activePower       67264 non-null  int64
#  3   activePowerDelta  67264 non-null  int64
#  4   reactivePower     67264 non-null  int64
#  5   apparentPower     67264 non-null  int64
#  6   current           67264 non-null  float64
#  7   voltage           67264 non-null  float64
#  8   phase             67264 non-null  float64
#  9   hertz             67264 non-null  int64
#  10  transient1        67264 non-null  float64
#  11  transient2        67264 non-null  float64
#  12  transient3        67264 non-null  float64
#  13  transient4        67264 non-null  float64
#  14  transient5        67264 non-null  float64
#  15  transient6        67264 non-null  float64
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
# read vw_train.csv

train_data_path = r'C:\Users\Latitude\Desktop\Kaggle\esda_nilm_2022\data\raw\vw_train.csv'
df = pd.read_csv(train_data_path, index_col=False, dtype={'id': int})
# explorative data analysis
# check shape of data, number of rows and columns, unique values, missing values, data types, etc.

df.shape 
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67264 entries, 0 to 67263
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        67264 non-null  int64
#  1   id                67264 non-null  int32
#  2   activePower       67264 non-null  int64
#  3   activePowerDelta  67264 non-null  int64
#  4   reactivePower     67264 non-null  int64
#  5   apparentPower     67264 non-null  int64
#  6   current           67264 non-null  float64
#  7   voltage           67264 non-null  float64
#  8   phase             67264 non-null  float64
#  9   hertz             67264 non-null  int64
#  10  transient1        67264 non-null  float64
#  11  transient2        67264 non-null  float64
#  12  transient3        67264 non-null  float64
#  13  transient4        67264 non-null  float64
#  14  transient5        67264 non-null  float64
#  15  transient6        67264 non-null  float64
# ...
